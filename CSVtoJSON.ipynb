# %%
import csv
import json
import pandas as pd

# %%
# Files to load
symptom_data_to_load = "Dash_Resources/CleanedDataSymptoms.csv"
lifestyle_data_to_load = "Dash_Resources/CleanedData.csv"

# %%
all_data_df = pd.read_csv(symptom_data_to_load)
all_data_df.head()
# Out:
#    Unnamed: 0 Patient Id  Age  Gender  Air Pollution  Alcohol use  \
# 0           0         P1   33       1              2            4
# 1           1        P10   17       1              3            1
# 2           2       P100   35       1              4            5
# 3           3      P1000   37       1              7            7
# 4           4       P101   46       1              6            8
#
#    Dust Allergy  OccuPational Hazards  Genetic Risk  chronic Lung Disease  \
# 0             5                     4             3                     2
# 1             5                     3             4                     2
# 2             6                     5             5                     4
# 3             7                     7             6                     7
# 4             7                     7             7                     6
#
#    ...  Fatigue  Weight Loss  Shortness of Breath  Wheezing  \
# ...

# %%
lifestyle_data_df = pd.read_csv(lifestyle_data_to_load)
lifestyle_data_df.head()
# Out:
#    Unnamed: 0 Patient Id  Age  Gender  Air Pollution  Alcohol use  \
# 0           0         P1   33       1              2            4
# 1           1        P10   17       1              3            1
# 2           2       P100   35       1              4            5
# 3           3      P1000   37       1              7            7
# 4           4       P101   46       1              6            8
#
#    Dust Allergy  OccuPational Hazards  Genetic Risk  chronic Lung Disease  \
# 0             5                     4             3                     2
# 1             5                     3             4                     2
# 2             6                     5             5                     4
# 3             7                     7             6                     7
# 4             7                     7             7                     6
#
#    Balanced Diet  Obesity  Smoking  Passive Smoker  Cancer Severity
# ...

# %% [markdown]
# Generate Symptom df

# %%
all_data_df.dtypes
# Out:
# Unnamed: 0                   int64
# Patient Id                  object
# Age                          int64
# Gender                       int64
# Air Pollution                int64
# Alcohol use                  int64
# Dust Allergy                 int64
# OccuPational Hazards         int64
# Genetic Risk                 int64
# chronic Lung Disease         int64
# Balanced Diet                int64
# Obesity                      int64
# Smoking                      int64
# Passive Smoker               int64
# Chest Pain                   int64
# Coughing of Blood            int64
# Fatigue                      int64
# Weight Loss                  int64
# Shortness of Breath          int64
# Wheezing                     int64
# Swallowing Difficulty        int64
# Clubbing of Finger Nails     int64
# Frequent Cold                int64
# Dry Cough                    int64
# Snoring                      int64
# Cancer Severity              int64
# dtype: object

# %%
#drop 'unnamed','Age','Gender', 'Cancer Severity' columns from all_data_df 
all_data_df.drop(all_data_df.columns[[0,2,3,25]], inplace=True, axis=1)
all_data_df.head()
# Out:
#   Patient Id  Air Pollution  Alcohol use  Dust Allergy  OccuPational Hazards  \
# 0         P1              2            4             5                     4
# 1        P10              3            1             5                     3
# 2       P100              4            5             6                     5
# 3      P1000              7            7             7                     7
# 4       P101              6            8             7                     7
#
#    Genetic Risk  chronic Lung Disease  Balanced Diet  Obesity  Smoking  ...  \
# 0             3                     2              2        4        3  ...
# 1             4                     2              2        2        2  ...
# 2             5                     4              6        7        2  ...
# 3             6                     7              7        7        7  ...
# 4             7                     6              7        7        8  ...
#
# ...

# %%
#drop lifestyle choices columns from all_data_df 
all_data_df.drop(all_data_df.iloc[:,1:11], inplace=True, axis=1)
all_data_df.head()
# Out:
#   Patient Id  Chest Pain  Coughing of Blood  Fatigue  Weight Loss  \
# 0         P1           2                  4        3            4
# 1        P10           2                  3        1            3
# 2       P100           4                  8        8            7
# 3      P1000           7                  8        4            2
# 4       P101           7                  9        3            2
#
#    Shortness of Breath  Wheezing  Swallowing Difficulty  \
# 0                    2         2                      3
# 1                    7         8                      6
# 2                    9         2                      1
# 3                    3         1                      4
# 4                    4         1                      4
#
#    Clubbing of Finger Nails  Frequent Cold  Dry Cough  Snoring
# 0                         1              2          3        4
# 1                         2              1          7        2
# ...

# %%
# edit column heads to make HTML calls easier
#all_data_df.columns = all_data_df.columns.str.replace(' ', '_')
#list(all_data_df)

# %%
#edit patient id column
all_data_df.rename(columns={"Patient Id":"Patient_Id"}, inplace = True)
list(all_data_df)
# Out:
# ['Patient_Id',
#  'Chest Pain',
#  'Coughing of Blood',
#  'Fatigue',
#  'Weight Loss',
#  'Shortness of Breath',
#  'Wheezing',
#  'Swallowing Difficulty',
#  'Clubbing of Finger Nails',
#  'Frequent Cold',
#  'Dry Cough',
#  'Snoring']

# %% [markdown]
# Prep lifestyle choices data

# %%
#drop 'unnamed' and 'Gender' columns from lifestyle_choices 
lifestyle_data_df.drop(lifestyle_data_df.columns[[0,2,3]], inplace=True, axis=1)
lifestyle_data_df.head()
# Out:
#   Patient Id  Air Pollution  Alcohol use  Dust Allergy  OccuPational Hazards  \
# 0         P1              2            4             5                     4
# 1        P10              3            1             5                     3
# 2       P100              4            5             6                     5
# 3      P1000              7            7             7                     7
# 4       P101              6            8             7                     7
#
#    Genetic Risk  chronic Lung Disease  Balanced Diet  Obesity  Smoking  \
# 0             3                     2              2        4        3
# 1             4                     2              2        2        2
# 2             5                     4              6        7        2
# 3             6                     7              7        7        7
# 4             7                     6              7        7        8
#
#    Passive Smoker  Cancer Severity
# 0               2                1
# ...

# %%
# edit column heads to make HTML calls easier
#lifestyle_data_df.columns = lifestyle_data_df.columns.str.replace(' ', '_')
#list(lifestyle_data_df)

# %%
#edit patient id column
lifestyle_data_df.rename(columns={"Patient Id":"Patient_Id", "OccuPational Hazards":"Occupational Hazards", "chronic Lung Disease": "Chronic Lung Disease", "Cancer Severity":"Cancer_Severity"}, inplace = True)
list(lifestyle_data_df)
# Out:
# ['Patient_Id',
#  'Air Pollution',
#  'Alcohol use',
#  'Dust Allergy',
#  'Occupational Hazards',
#  'Genetic Risk',
#  'Chronic Lung Disease',
#  'Balanced Diet',
#  'Obesity',
#  'Smoking',
#  'Passive Smoker',
#  'Cancer_Severity']

# %%
# converting to JSON
#all_data_df.to_json(
#    path_or_buf='all_data.json',
#    orient='split',  # other options are (split’, ‘records’, ‘index’, ‘columns’, ‘values’, ‘table’)
#    date_format='epoch',
#    double_precision = 2,
#    force_ascii=False,
#    date_unit='ms',
#    default_handler=None,
#    lines=False, # orient must be records to set this True
#    #compression='zip',
#    index=False, # it works only when orient is split or table
#    indent=2    
#)

# %% [markdown]
# Patient ID dict

# %%
p_id = []

# %%
patient_id = all_data_df["Patient_Id"]
patient_id
# Out:
# 0         P1
# 1        P10
# 2       P100
# 3      P1000
# 4       P101
#        ...
# 995     P995
# 996     P996
# 997     P997
# 998     P998
# 999     P999
# Name: Patient_Id, Length: 1000, dtype: object

# %%
for name in patient_id:
    p_id.append(name)

# %%
# convert dict to json
#pid_json = json.dumps(p_id)
#print(pid_json)

# %% [markdown]
# Symptom Metadata

# %%
symptom_data =all_data_df.to_dict('records')
symptom_data
# Out:
# [{'Patient_Id': 'P1',
#   'Chest Pain': 2,
#   'Coughing of Blood': 4,
#   'Fatigue': 3,
#   'Weight Loss': 4,
#   'Shortness of Breath': 2,
#   'Wheezing': 2,
#   'Swallowing Difficulty': 3,
#   'Clubbing of Finger Nails': 1,
#   'Frequent Cold': 2,
#   'Dry Cough': 3,
#   'Snoring': 4},
#  {'Patient_Id': 'P10',
#   'Chest Pain': 2,
#   'Coughing of Blood': 3,
#   'Fatigue': 1,
#   'Weight Loss': 3,
#   'Shortness of Breath': 7,
#   'Wheezing': 8,
#   'Swallowing Difficulty': 6,
#   'Clubbing of Finger Nails': 2,
#   'Frequent Cold': 1,
#   'Dry Cough': 7,
#   'Snoring': 2},
#  {'Patient_Id': 'P100',
#   'Chest Pain': 4,
#   'Coughing of Blood': 8,
#   'Fatigue': 8,
#   'Weight Loss': 7,
#   'Shortness of Breath': 9,
#   'Wheezing': 2,
#   'Swallowing Difficulty': 1,
#   'Clubbing of Finger Nails': 4,
#   'Frequent Cold': 6,
#   'Dry Cough': 7,
#   'Snoring': 2},
#  {'Patient_Id': 'P1000',
#   'Chest Pain': 7,
#   'Coughing of Blood': 8,
#   'Fatigue': 4,
#   'Weight Loss': 2,
# ...

# %%
# symptom metadata for json
#symptom_data =all_data_df.to_json(indent=1, orient= 'records')
#parsed1 = json.loads(symptom_data)
#symptom = json.dumps(parsed1)
#symptom

# %%
bar_data = lifestyle_data_df.to_dict('records')
bar_data
# Out:
# [{'Patient_Id': 'P1',
#   'Air Pollution': 2,
#   'Alcohol use': 4,
#   'Dust Allergy': 5,
#   'Occupational Hazards': 4,
#   'Genetic Risk': 3,
#   'Chronic Lung Disease': 2,
#   'Balanced Diet': 2,
#   'Obesity': 4,
#   'Smoking': 3,
#   'Passive Smoker': 2,
#   'Cancer_Severity': 1},
#  {'Patient_Id': 'P10',
#   'Air Pollution': 3,
#   'Alcohol use': 1,
#   'Dust Allergy': 5,
#   'Occupational Hazards': 3,
#   'Genetic Risk': 4,
#   'Chronic Lung Disease': 2,
#   'Balanced Diet': 2,
#   'Obesity': 2,
#   'Smoking': 2,
#   'Passive Smoker': 4,
#   'Cancer_Severity': 2},
#  {'Patient_Id': 'P100',
#   'Air Pollution': 4,
#   'Alcohol use': 5,
#   'Dust Allergy': 6,
#   'Occupational Hazards': 5,
#   'Genetic Risk': 5,
#   'Chronic Lung Disease': 4,
#   'Balanced Diet': 6,
#   'Obesity': 7,
#   'Smoking': 2,
#   'Passive Smoker': 3,
#   'Cancer_Severity': 3},
#  {'Patient_Id': 'P1000',
#   'Air Pollution': 7,
#   'Alcohol use': 7,
#   'Dust Allergy': 7,
#   'Occupational Hazards': 7,
# ...

# %%
#bar_data =lifestyle_data_df.to_json(indent=1, orient= 'records')
#parsed = json.loads(bar_data)
#bar_graph = json.dumps(parsed)
#bar_graph

# %%
# creating dictionary for all data
all_data = {
    "patients" : p_id,
    "symptoms" : symptom_data,
    "lifestyle" : bar_data
}
all_data
# Out:
# {'patients': ['P1',
#   'P10',
#   'P100',
#   'P1000',
#   'P101',
#   'P102',
#   'P103',
#   'P104',
#   'P105',
#   'P106',
#   'P107',
#   'P108',
#   'P109',
#   'P11',
#   'P110',
#   'P111',
#   'P112',
#   'P113',
#   'P114',
#   'P115',
#   'P116',
#   'P117',
#   'P118',
#   'P119',
#   'P12',
#   'P120',
#   'P121',
#   'P122',
#   'P123',
#   'P124',
#   'P125',
#   'P126',
#   'P127',
#   'P128',
#   'P129',
#   'P13',
#   'P130',
#   'P131',
#   'P132',
#   'P133',
#   'P134',
#   'P135',
#   'P136',
#   'P137',
#   'P138',
#   'P139',
#   'P14',
#   'P140',
#   'P141',
#   'P142',
#   'P143',
#   'P144',
#   'P145',
#   'P146',
#   'P147',
#   'P148',
#   'P149',
#   'P15',
#   'P150',
#   'P151',
#   'P152',
#   'P153',
#   'P154',
#   'P155',
#   'P156',
#   'P157',
#   'P158',
#   'P159',
#   'P16',
#   'P160',
#   'P161',
#   'P162',
#   'P163',
#   'P164',
#   'P165',
#   'P166',
#   'P167',
#   'P168',
#   'P169',
#   'P17',
#   'P170',
#   'P171',
#   'P172',
# ...

# %%
#save dictionary as json file
with open("samples.json", "w") as outfile:
    json.dump(all_data, outfile)
